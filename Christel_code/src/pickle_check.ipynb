# %%
import pickle

# %%
filepath = '../data/processed/physionet_2012.pkl'
data, oc, train_ids, val_ids, test_ids = pickle.load(open(filepath,'rb'))

# %%
print(len(train_ids))
print(len(val_ids))
print(len(test_ids))
# Out:
# 3997
# 5750
# 1441
